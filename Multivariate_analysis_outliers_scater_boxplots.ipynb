# %%
import pandas as pd

import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sb

# %%
# %matplotlib inline
rcParams['figure.figsize'] = 5,4
sb.set_style('whitegrid')

# %%
iris_df = pd.read_csv("iris.data.csv",header=None)
iris_df.columns = ['Sepal length','Sepal width','Petal length','Petal width','species']
iris_df.head()
# Out:
#    Sepal length  Sepal width  Petal length  Petal width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
data=iris_df.iloc[:,0:4]
target=iris_df.iloc[:,4]
print(data.head())
print(target.head())

print(data.shape)
print(target.shape)
# Out:
#    Sepal length  Sepal width  Petal length  Petal width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2
# 0    setosa
# 1    setosa
# 2    setosa
# 3    setosa
# 4    setosa
# Name: species, dtype: object
# (150, 4)
# (150L,)

# %%
# Plotting box plot with 2 variables, 1 - species, 2 - sepal length
sb.boxplot(x='species',y='Sepal length',data=iris_df,palette='hls')

# %%
# Plotting scatter plot -- hue will color the data based on species
sb.pairplot(iris_df,hue='species',palette='hls')
